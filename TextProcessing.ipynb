# %%
import numpy as np 
import pandas as pd
import math 
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import glob
import os
import string
import sys
import random
import math
from stemming.porter2 import stem
stopwords_f = open('common-english-words.txt', 'r') 
stop= stopwords_f.read().split(',')

def clean_df(df):
    query_dict={}
    for i in range(len(df['text'])): 
        u={}

        temp=df['text'][i].strip()
        temp=temp.split()

        for term in temp: 
            term = term.translate(str.maketrans('','', string.digits)).translate(str.maketrans(string.punctuation, ' '*len(string.punctuation)))
            term = term.replace("\\s+", " ")
            term = term.strip()
            term = stem(term.lower())

            if len(term) > 2 and term not in stop:
                try:
                    u[term] += 1/len(temp)
                except KeyError:
                    u[term] = 1/len(temp)
        query_dict[df['index'][i]]=u
    return query_dict

# %%
df=pd.read_csv('AMI_train.csv')
df.reset_index(inplace=True)

# %%
clean_df(df)
# Out:
# {0: {'maisonmargieia': 0.07142857142857142,
#   'wow': 0.07142857142857142,
#   'hoe': 0.07142857142857142,
#   'aint': 0.07142857142857142,
#   'shit': 0.07142857142857142,
#   'deserv': 0.07142857142857142,
#   'better': 0.07142857142857142,
#   'dan': 0.07142857142857142,
#   'ugli': 0.07142857142857142,
#   'whore': 0.07142857142857142,
#   'brother': 0.07142857142857142},
#  1: {'bitch': 0.14285714285714285,
#   'out': 0.14285714285714285,
#   'hell': 0.14285714285714285,
#   'hole': 0.14285714285714285},
#  2: {'msnbc': 0.07142857142857142,
#   'peopl': 0.03571428571428571,
#   'pos': 0.03571428571428571,
#   'liar': 0.03571428571428571,
#   'more': 0.03571428571428571,
#   'fake': 0.03571428571428571,
#   'news': 0.03571428571428571,
#   'offer': 0.07142857142857142,
#   'women': 0.03571428571428571,
#   'obama': 0.03571428571428571,
#   'skank': 0.03571428571428571,
#   'wife': 0.03571428571428571,
#   'take': 0.03571428571428571},
#  3: {'peartopear': 0.08333333333333333,
# ...
